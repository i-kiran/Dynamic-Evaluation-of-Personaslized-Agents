# %% [markdown]
# # AutoGen Check

# %%
# %pip install "autogen-ext[openai,azure]"
# %pip install azure-identity
# %pip install autogen_ext
# Out:
# Requirement already satisfied: autogen-ext[azure,openai] in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: autogen-core==0.5.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (0.5.0)
# Requirement already satisfied: aiofiles in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (24.1.0)
# Requirement already satisfied: openai>=1.66.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (1.70.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (0.9.0)
# Requirement already satisfied: azure-ai-inference>=1.0.0b7 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (1.0.0b9)
# Requirement already satisfied: azure-core in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (1.31.0)
# Requirement already satisfied: azure-identity in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (1.18.0)
# Requirement already satisfied: azure-search-documents>=11.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-ext[azure,openai]) (11.5.2)
# Requirement already satisfied: jsonref~=1.1.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen-ext[azure,openai]) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen-ext[azure,openai]) (1.27.0)
# Requirement already satisfied: pillow>=11.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen-ext[azure,openai]) (11.1.0)
# Requirement already satisfied: protobuf~=5.29.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen-ext[azure,openai]) (5.29.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen-ext[azure,openai]) (2.11.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen-ext[azure,openai]) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-ai-inference>=1.0.0b7->autogen-ext[azure,openai]) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-core->autogen-ext[azure,openai]) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-core->autogen-ext[azure,openai]) (1.16.0)
# Requirement already satisfied: azure-common>=1.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-search-documents>=11.4.0->autogen-ext[azure,openai]) (1.1.28)
# Requirement already satisfied: anyio<5,>=3.5.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from openai>=1.66.5->autogen-ext[azure,openai]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from openai>=1.66.5->autogen-ext[azure,openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from openai>=1.66.5->autogen-ext[azure,openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from openai>=1.66.5->autogen-ext[azure,openai]) (0.9.0)
# Requirement already satisfied: sniffio in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from openai>=1.66.5->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from openai>=1.66.5->autogen-ext[azure,openai]) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from tiktoken>=0.8.0->autogen-ext[azure,openai]) (2024.11.6)
# Requirement already satisfied: cryptography>=2.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity->autogen-ext[azure,openai]) (43.0.1)
# Requirement already satisfied: msal>=1.30.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity->autogen-ext[azure,openai]) (1.31.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity->autogen-ext[azure,openai]) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.66.5->autogen-ext[azure,openai]) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.66.5->autogen-ext[azure,openai]) (3.10)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (1.17.1)
# Requirement already satisfied: certifi in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.66.5->autogen-ext[azure,openai]) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.66.5->autogen-ext[azure,openai]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.66.5->autogen-ext[azure,openai]) (0.14.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->autogen-ext[azure,openai]) (2.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from msal-extensions>=1.2.0->azure-identity->autogen-ext[azure,openai]) (2.10.1)
# Requirement already satisfied: deprecated>=1.2.6 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (8.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (2.2.3)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen-ext[azure,openai]) (3.20.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-identity in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (1.18.0)
# Requirement already satisfied: azure-core>=1.31.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity) (1.31.0)
# Requirement already satisfied: cryptography>=2.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity) (43.0.1)
# Requirement already satisfied: msal>=1.30.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity) (1.31.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-identity) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from azure-core>=1.31.0->azure-identity) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: autogen_ext in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: autogen-core==0.5.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen_ext) (0.5.0)
# Requirement already satisfied: jsonref~=1.1.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen_ext) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen_ext) (1.27.0)
# Requirement already satisfied: pillow>=11.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen_ext) (11.1.0)
# Requirement already satisfied: protobuf~=5.29.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen_ext) (5.29.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen_ext) (2.11.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from autogen-core==0.5.0->autogen_ext) (4.12.2)
# Requirement already satisfied: deprecated>=1.2.6 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen_ext) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen_ext) (8.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.5.0->autogen_ext) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.5.0->autogen_ext) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.5.0->autogen_ext) (0.4.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen_ext) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.27.0->autogen-core==0.5.0->autogen_ext) (3.20.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install autogen
# Out:
# Collecting autogen
#   Downloading autogen-0.8.5-py3-none-any.whl.metadata (20 kB)
# Collecting pyautogen==0.8.5 (from autogen)
#   Downloading pyautogen-0.8.5-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: anyio<5.0.0,>=3.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (4.9.0)
# Collecting asyncer==0.0.8 (from pyautogen==0.8.5->autogen)
#   Downloading asyncer-0.0.8-py3-none-any.whl.metadata (6.7 kB)
# Collecting diskcache (from pyautogen==0.8.5->autogen)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: docker in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (7.1.0)
# Requirement already satisfied: httpx<1,>=0.28.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (0.28.1)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (24.1)
# Requirement already satisfied: pydantic<3,>=2.6.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (2.11.2)
# Requirement already satisfied: python-dotenv in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (1.0.1)
# Requirement already satisfied: termcolor in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (2.4.0)
# Requirement already satisfied: tiktoken in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pyautogen==0.8.5->autogen) (0.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from anyio<5.0.0,>=3.0.0->pyautogen==0.8.5->autogen) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from anyio<5.0.0,>=3.0.0->pyautogen==0.8.5->autogen) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from anyio<5.0.0,>=3.0.0->pyautogen==0.8.5->autogen) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from anyio<5.0.0,>=3.0.0->pyautogen==0.8.5->autogen) (4.12.2)
# Requirement already satisfied: certifi in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from httpx<1,>=0.28.1->pyautogen==0.8.5->autogen) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from httpx<1,>=0.28.1->pyautogen==0.8.5->autogen) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.28.1->pyautogen==0.8.5->autogen) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3,>=2.6.1->pyautogen==0.8.5->autogen) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3,>=2.6.1->pyautogen==0.8.5->autogen) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from pydantic<3,>=2.6.1->pyautogen==0.8.5->autogen) (0.4.0)
# Requirement already satisfied: requests>=2.26.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from docker->pyautogen==0.8.5->autogen) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from docker->pyautogen==0.8.5->autogen) (2.2.3)
# Requirement already satisfied: regex>=2022.1.18 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from tiktoken->pyautogen==0.8.5->autogen) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.10/site-packages (from requests>=2.26.0->docker->pyautogen==0.8.5->autogen) (3.3.2)
# Downloading autogen-0.8.5-py3-none-any.whl (12 kB)
# Downloading pyautogen-0.8.5-py3-none-any.whl (730 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.4/730.4 kB 24.1 MB/s eta 0:00:00
# Downloading asyncer-0.0.8-py3-none-any.whl (9.2 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
# Installing collected packages: diskcache, asyncer, pyautogen, autogen
# Successfully installed asyncer-0.0.8 autogen-0.8.5 diskcache-5.6.3 pyautogen-0.8.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
with open("Dataset/user_instructions.json", 'r') as f:
    user_profiles = json.load(f)
print("Number of users loaded:",len(user_profiles))

#find length of user_profiles test and train
print("Number of users in train:",len(user_profiles['train']))  
print("Number of users in test:",len(user_profiles['test']))

# merge user_profiles['train'] and user_profiles['test']
user_profiles['train'] += user_profiles['test']

#find length of user_profiles['train']
print("Final Number of users: ",len(user_profiles['train']))
# Out:
# Number of users loaded: 2
# Number of users in train: 6896
# Number of users in test: 2174
# Final Number of users:  9070

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import AssistantMessage, SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential
from autogen import ConversableAgent
import sys
import json
import numpy as np
import pandas as pd

# %%
os.environ["AZURE_OPENAI_API_KEY"] = "YOUR API"
os.environ["AZURE_OPENAI_API_BASE"] = "API BASE"
# Define the llm_config
config_list={
        "model": "gpt-4o-mini",
        "api_key": os.environ.get("AZURE_OPENAI_API_KEY"),
        "api_type": "azure",
        "base_url": os.environ.get("AZURE_OPENAI_API_BASE"),
        "api_version": "2025-01-01-preview",
    }

# %%
import json
import time
import sqlite3

# Retry for "database is locked" error
max_retries = 5
retry_delay = 2  # seconds

# Load JSON file
with open("Dataset/user_profiles.json", "r", encoding="utf-8") as file:
    personas = json.load(file)

def generate_prompt(user_profile):
    gender = user_profile["user_profile"].get("Gender", "Unknown").lower()
    pronoun = "they" if gender not in ["male", "female"] else "she" if gender == "female" else "he"
    
    return f"""
You are a shopper looking to purchase an item. Stay in character as a {user_profile["user_profile"].get('Age', 'unknown age')}-year-old {gender} {user_profile["user_profile"].get('Occupation', 'individual')}.
Your goal is to find the best option based on your preferences, price sensitivity ({user_profile["user_profile"].get('Price Sensitivity', 'unknown')}), and shopping interests ({user_profile["user_profile"].get('Shopping Interest', 'various categories')}).
When responding:
- Provide information about your preferences, interests, and constraints.
- Ask questions about product details, discounts, or comparisons.
- Express opinions and react naturally to recommendations.
- Do **not** provide recommendations or act like an assistant.
- Keep your tone {user_profile["user_profile"].get('Tone and Style', 'neutral')}.
- If unsure, ask for clarification rather than making recommendations.
"""

# Process all personas
for user in personas:
    persona = personas[user]
    sys_message = generate_prompt(persona)

    user_proxy = ConversableAgent(
        "user",
        system_message = sys_message,
        llm_config = config_list,
        human_input_mode = "NEVER",
        description="You are a shopper trying to present their preferences and constraints to a shopping assistant.",
    )

    shopping_assistant = ConversableAgent(
        "assistant",
        system_message=(
            "You are a highly capable shopping assistant designed to help users with their shopping needs. "
            "Your primary work task is to assist end users in their shopping journey by handling three core subtasks: "
            "1. Product Discovery: Identify and suggest relevant products based on user preferences. "
            "2. Price Comparison: Provide competitive price analysis across multiple vendors. "
            "3. Personalized Recommendations: Tailor suggestions based on user history, preferences, and context. "
            "\nTo achieve these tasks, you must conduct a structured reference interview to elicit user needs, including their prefernces "
            "like preferred brands, price range, product features, shopping urgency, and other relevant factors. "
            "Your goal is to efficiently gather *** yser's needs, requirements and preferences*** without overwhelming the user. Ask few questions at a time. "
        ),
        llm_config=config_list,
        human_input_mode="NEVER",  # Never ask for human input.
    )
    # For every user in personas, check if the user is in user_profiles['train']
    print(f"Checking user: {user}")
    
    # Look for user in user_profiles['train'] where user is a key named as user_id
    found = any(profile.get('user_id') == user for profile in user_profiles['train'])
    #extract 'task' corresponding to user in user_profiles['train']
    task = [profile['task'] for profile in user_profiles['train'] if profile.get('user_id') == user]
    print("Task:",task[0])
    print("Task1:",task[1])
    
    if found:
        print("User found in train")
    else:
        print("User not found in train")
    # user_query = task[0]
    # result = user_proxy.initiate_chat(shopping_assistant, message= user_query , max_turns=5)

    for attempt in range(max_retries):
        try:
            result = user_proxy.initiate_chat(shopping_assistant, message=user_query, max_turns=5)
            break  # if successful, exit loop
        except sqlite3.OperationalError as e:
            if "database is locked" in str(e):
                print(f"[Attempt {attempt+1}] Database is locked, retrying in {retry_delay} seconds...")
                time.sleep(retry_delay)
            else:
                raise
        else:
            print("Failed after multiple retries due to database lock.")
            result = None

    # Save chat history in a text file
    with open(f"Results_referenceInterview/{user}.txt", 'w') as f_txt:
        for message in result.chat_history:
            f_txt.write(f"{message['role'].capitalize()}: {message['content']}\n\n")
